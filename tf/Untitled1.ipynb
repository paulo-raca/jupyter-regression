# %%
import pandas as pd
import sympy
from data_fit import DataFit
import sympy.physics.units as units
import tensorboard

# %%
datafit = DataFit()
datafit.add_experimental_data("x", units.meter, "Displacement")
datafit.add_experimental_data("F_exp", units.newton, "Measured Force")
datafit.add_parameter("k", units.newton/units.meter, "Sprint constant")
datafit.add_expr("F", units.newton, datafit.k * datafit.x, "Predicted force")
datafit.add_optimization_objective("F_MSE", units.newton, datafit.F_exp, datafit.F)
data = pd.DataFrame(data=dict(
    F_exp=[1,2,3,4], x=[1.1,2.1,3.1,4.1]
))
#datafit.fit(data)

# %%
datafit = DataFit()
datafit.add_experimental_data("X_exp", units.meter, "Measured distance")
datafit.add_experimental_data("t", units.seconds, "Time")
datafit.add_parameter("X_0", units.meter, "Initial distance")
datafit.add_parameter("V_0", units.meter / units.second, "Initial speed")
datafit.add_parameter("A", units.meter / units.second**2, "aceleration")
datafit.add_differential_expr("V", units.meter/units.second, datafit.A, datafit.t, datafit.V_0, "V(t)")
datafit.add_differential_expr("X", units.meter, datafit.V_0 + datafit.A * datafit.t, datafit.t, datafit.X_0, "X(t)")
datafit.add_optimization_objective("F_MSE", units.meter, datafit.X_exp, datafit.X)
data = pd.DataFrame(data=dict(
    t=[1,2,3,4,5,6,7], X_exp=[1.1,2.1,3.1,4.1,5.1,6.1,7.1]
))
datafit.fit(data, 5000)
#print()
# Out:
# {'X_0': 0.10000007496379291,
#  'V_0': 0.9999999091362025,
#  'A': 1.637006127942066e-08,
#  'V': array([0.99999993, 0.99999994, 0.99999996, 0.99999997, 0.99999999,
#         1.00000001, 1.00000002]),
#  'X': array([1.09999999, 2.09999993, 3.09999988, 4.09999984, 5.09999983,
#         6.09999982, 7.09999984]),
#  'F_MSE': 0.0}

# %%
tensorboard.show_graph(datafit.to_tensorflow()[0])
# Out:
#         <iframe seamless style="width:100%;height:800px;border:0" srcdoc='&#10;        &lt;script&gt;&#10;          function load() {&#10;            document.getElementById("tf-graph").pbtxt = "node {\n  name: \"output_parameters/A/initial_value\"\n  op: \"Const\"\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"value\"\n    value {\n      tensor {\n        dtype: DT_DOUBLE\n        tensor_shape {\n        }\n        double_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: \"output_parameters/A\"\n  op: \"VariableV2\"\n  attr {\n    key: \"container\"\n    value {\n      s: \"\"\n    }\n  }\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"shape\"\n    value {\n      shape {\n      }\n    }\n  }\n  attr {\n    key: \"shared_name\"\n    value {\n      s: \"\"\n    }\n  }\n}\nnode {\n  name: \"output_parameters/A/Assign\"\n  op: \"Assign\"\n  input: \"output_parameters/A\"\n  input: \"output_parameters/A/initial_value\"\n  attr {\n    key: \"T\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"_class\"\n    value {\n      list {\n        s: \"loc:@output_parameters/A\"\n      }\n    }\n  }\n  attr {\n    key: \"use_locking\"\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: \"validate_shape\"\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: \"output_parameters/A/read\"\n  op: \"Identity\"\n  input: \"output_parameters/A\"\n  attr {\n    key: \"T\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"_class\"\n    value {\n      list {\n        s: \"loc:@output_parameters/A\"\n      }\n    }\n  }\n}\nnode {\n  name: \"output_parameters/V_0/initial_value\"\n  op: \"Const\"\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"value\"\n    value {\n      tensor {\n        dtype: DT_DOUBLE\n        tensor_shape {\n        }\n        double_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: \"output_parameters/V_0\"\n  op: \"VariableV2\"\n  attr {\n    key: \"container\"\n    value {\n      s: \"\"\n    }\n  }\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"shape\"\n    value {\n      shape {\n      }\n    }\n  }\n  attr {\n    key: \"shared_name\"\n    value {\n      s: \"\"\n    }\n  }\n}\nnode {\n  name: \"output_parameters/V_0/Assign\"\n  op: \"Assign\"\n  input: \"output_parameters/V_0\"\n  input: \"output_parameters/V_0/initial_value\"\n  attr {\n    key: \"T\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"_class\"\n    value {\n      list {\n        s: \"loc:@output_parameters/V_0\"\n      }\n    }\n  }\n  attr {\n    key: \"use_locking\"\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: \"validate_shape\"\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: \"output_parameters/V_0/read\"\n  op: \"Identity\"\n  input: \"output_parameters/V_0\"\n  attr {\n    key: \"T\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"_class\"\n    value {\n      list {\n        s: \"loc:@output_parameters/V_0\"\n      }\n    }\n  }\n}\nnode {\n  name: \"output_parameters/X_0/initial_value\"\n  op: \"Const\"\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"value\"\n    value {\n      tensor {\n        dtype: DT_DOUBLE\n        tensor_shape {\n        }\n        double_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: \"output_parameters/X_0\"\n  op: \"VariableV2\"\n  attr {\n    key: \"container\"\n    value {\n      s: \"\"\n    }\n  }\n  attr {\n    key: \"dtype\"\n    value {\n      type: DT_DOUBLE\n    }\n  }\n  attr {\n    key: \"shape\"\n    value {\n      shape {\n      }\n    }\n  }\n  attr {\n    key: \"shared_name\"\n    value {\n      s: \"\"\n    }\n  }\n}\nnode {\n  name: \"output_parameters/X_0/Assign\"\n  op: \"Assign\"\n  input: \"output_parameters/X_0\"\n  input:  ...

# %%
import tensorflow as tf
tf.enable_eager_execution()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2f19147a4fbd> in <module>
#       1 import tensorflow as tf
# ----> 2 tf.enable_eager_execution()
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in enable_eager_execution(config, device_policy, execution_mode)
#    5421         device_policy=device_policy,
#    5422         execution_mode=execution_mode,
# -> 5423         server_def=None)
#    5424
#    5425
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in enable_eager_execution_internal(config, device_policy, execution_mode, server_def)
#    5489   else:
#    5490     raise ValueError(
# -> 5491         "tf.enable_eager_execution must be called at program startup.")
#    5492
#    5493   # Monkey patch to get rid of an unnecessary conditional since the context is
#
# ValueError: tf.enable_eager_execution must be called at program startup.

# %%
tf.contrib.integrate.odeint(lambda y, _: -y, 1., [0.1, 1., 2.])
#=> [1, exp(-1), exp(-2)]
